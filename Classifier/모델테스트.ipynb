# %%
from fastai.vision import *

# %%
import os
import secrets
import torch
import torchvision
from flask import render_template, url_for, flash, redirect, request
from flask_uploads import UploadSet, configure_uploads, IMAGES
from classifier import app, db
from classifier.forms import ImageUploadForm
from classifier.models import User
from flask_login import login_user, current_user, logout_user, login_required
# Out:
# C:\Users\Hwayoung\Anaconda3\lib\site-packages\flask_sqlalchemy\__init__.py:834: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %%
from flask import Flask
from flask_sqlalchemy import SQLAlchemy

app = Flask(__name__)
app.config['SECRET_KEY'] = '5791628bb0b13ce0c676dfde280ba245'
app.config['SQLALCHEMY_DATABASE_URI'] = 'sqlite:///site.db'
db = SQLAlchemy(app)
# Out:
# C:\Users\Hwayoung\Anaconda3\lib\site-packages\flask_sqlalchemy\__init__.py:834: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %%
path=Path('classifier/data')

# %%
learn = load_learner(path)
# Out:
# C:\Users\Hwayoung\Anaconda3\lib\site-packages\torch\serialization.py:657: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
picture_path = os.path.join(app.root_path,'classifier/static/pics','2018032202713_0.jpg')

# %%
picture_path
# Out:
# 'C:\\Users\\Hwayoung\\00_FastAi\\Classifier\\classifier/static/pics\\2018032202713_0.jpg'

# %%
img = open_image(picture_path)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-116-76653e0181b1> in <module>
# ----> 1 img = open_image('classifier/static/pics', 'default.jpg' )
#
# ~\Anaconda3\lib\site-packages\fastai\vision\image.py in open_image(fn, div, convert_mode, cls, after_open)
#     396     with warnings.catch_warnings():
#     397         warnings.simplefilter("ignore", UserWarning) # EXIF warning from TiffPlugin
# --> 398         x = PIL.Image.open(fn).convert(convert_mode)
#     399     if after_open: x = after_open(x)
#     400     x = pil2tensor(x,np.float32)
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# PermissionError: [Errno 13] Permission denied: 'classifier/static/pics'

# %%
img
# Out:
# Image (3, 315, 236)

# %%
pred_class,pred_idx,outputs = learn.predict(img)

# %%
print(pred_class)
# Out:
# BongsunShin

# %%
pred_class
# Out:
# Category tensor(0)
